# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.4903, 0.9988, 0.2521],
#         [0.0872, 0.7482, 0.2694],
#         [0.1891, 0.7538, 0.3408],
#         [0.4478, 0.9999, 0.6353],
#         [0.5929, 0.6617, 0.6941]])
