# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()
print(x)
# Out:
# [4.64758392 4.92742578 4.00957647 ... 6.43595557 3.78490164 5.11197995]
