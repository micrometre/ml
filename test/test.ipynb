# %%
import matplotlib
import numpy
import pandas
import scipy
print(matplotlib.__version__)
print(pandas.__version__)
print(matplotlib.__version__)
print(scipy.__version__)
# Out:
# 3.7.1
# 2.0.1
# 3.7.1
# 1.10.1
