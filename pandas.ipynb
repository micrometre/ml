# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.9336, 0.2224, 0.0573],
#         [0.6769, 0.1164, 0.7806],
#         [0.9222, 0.1059, 0.4116],
#         [0.4954, 0.3505, 0.3879],
#         [0.5110, 0.8462, 0.7443]])
